# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)


class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description="Save under images/, e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"


class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)

    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str


# -----------------------------
# 2) LLM
# -----------------------------

import os

os.environ["OPENAI_API_KEY"] = "sk_your_key_please"
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
llm.invoke("hhl")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 9, 'total_tokens': 18, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_d96d8e3578', 'id': 'chatcmpl-DBSAzoZnYlllMduxk3nNmzNyobRbV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6b14a2ee-6408-4da6-93bf-212395d2d9c2-0', usage_metadata={'input_tokens': 9, 'output_tokens': 9, 'total_tokens': 18, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------

import os
os.environ["api_key"] = "t_your_key_please"
api = os.getenv("api_key")
# 4) Research (Tavily) 
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(tavily_api_key = api, max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# ============================================================
# 8) ReducerWithImages (subgraph)
#    merge_content -> decide_images -> generate_and_place_images
# ============================================================
def merge_content(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    merged_md = f"# {plan.blog_title}\n\n{body}\n"
    return {"merged_md": merged_md}


DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.
Decide if images/diagrams are needed for THIS blog.

Rules:
- Max 3 images total.
- Each image must materially improve understanding (diagram/flow/table-like visual).
- Insert placeholders exactly: [[IMAGE_1]], [[IMAGE_2]], [[IMAGE_3]].
- If no images needed: md_with_placeholders must equal input and images=[].
- Avoid decorative images; prefer technical diagrams with short labels.
Return strictly GlobalImagePlan.
"""

def decide_images(state: State) -> dict:
    
    planner = llm.with_structured_output(GlobalImagePlan)
    merged_md = state["merged_md"]
    plan = state["plan"]
    assert plan is not None

    image_plan = planner.invoke(
        [
            SystemMessage(content=DECIDE_IMAGES_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    return {
        "md_with_placeholders": image_plan.md_with_placeholders,
        "image_specs": [img.model_dump() for img in image_plan.images],
    }


def _gemini_generate_image_bytes(prompt: str) -> bytes:
    """
    Returns raw image bytes generated by Gemini.
    Requires: pip install google-genai
    Env var: GOOGLE_API_KEY
    """
    from google import genai
    from google.genai import types
    os.environ["GOOGLE_API_KEY"] = "gg_your_key_please"

    api_key = os.environ.get("GOOGLE_API_KEY")
    if not api_key:
        raise RuntimeError("GOOGLE_API_KEY is not set.")

    client = genai.Client(api_key=api_key)

    resp = client.models.generate_content(
        model="gemini-2.5-flash-image",
        contents=prompt,
        config=types.GenerateContentConfig(
            response_modalities=["IMAGE"],
            safety_settings=[
                types.SafetySetting(
                    category="HARM_CATEGORY_DANGEROUS_CONTENT",
                    threshold="BLOCK_ONLY_HIGH",
                )
            ],
        ),
    )

    # Depending on SDK version, parts may hang off resp.candidates[0].content.parts
    parts = getattr(resp, "parts", None)
    if not parts and getattr(resp, "candidates", None):
        try:
            parts = resp.candidates[0].content.parts
        except Exception:
            parts = None

    if not parts:
        raise RuntimeError("No image content returned (safety/quota/SDK change).")

    for part in parts:
        inline = getattr(part, "inline_data", None)
        if inline and getattr(inline, "data", None):
            return inline.data

    raise RuntimeError("No inline image bytes found in response.")


def generate_and_place_images(state: State) -> dict:

    plan = state["plan"]
    assert plan is not None

    md = state.get("md_with_placeholders") or state["merged_md"]
    image_specs = state.get("image_specs", []) or []

    # If no images requested, just write merged markdown
    if not image_specs:
        filename = f"{plan.blog_title}.md"
        Path(filename).write_text(md, encoding="utf-8")
        return {"final": md}

    images_dir = Path("images")
    images_dir.mkdir(exist_ok=True)

    for spec in image_specs:
        placeholder = spec["placeholder"]
        filename = spec["filename"]
        out_path = images_dir / filename

        # generate only if needed
        if not out_path.exists():
            try:
                img_bytes = _gemini_generate_image_bytes(spec["prompt"])
                out_path.write_bytes(img_bytes)
            except Exception as e:
                # graceful fallback: keep doc usable
                prompt_block = (
                    f"> **[IMAGE GENERATION FAILED]** {spec.get('caption','')}\n>\n"
                    f"> **Alt:** {spec.get('alt','')}\n>\n"
                    f"> **Prompt:** {spec.get('prompt','')}\n>\n"
                    f"> **Error:** {e}\n"
                )
                md = md.replace(placeholder, prompt_block)
                continue

        img_md = f"![{spec['alt']}](images/{filename})\n*{spec['caption']}*"
        md = md.replace(placeholder, img_md)

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(md, encoding="utf-8")
    return {"final": md}

# %%
# build reducer subgraph
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)
reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
# -----------------------------
# 9) Build main graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,
            "sections": [],
            "merged_md": "",
            "md_with_placeholders": "",
            "image_specs": [],
            "final": "",
        }
    )

    return out

# %%
run("Self Attention in Transformer Architecture")
# Out:
# {'topic': 'Self Attention in Transformer Architecture',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Understanding Self-Attention in Transformer Architecture', audience='Developers with intermediate to advanced knowledge in machine learning and deep learning', tone='Informative and precise', blog_kind='explainer', constraints=['Use precise technical terminology appropriate for machine learning practitioners', 'Provide actionable insights and technical depth', 'Include minimal working examples where relevant', 'Cover performance and debugging considerations'], tasks=[Task(id=1, title='Introduction to Self-Attention Mechanism', goal='Explain the fundamental concept and importance of self-attention within transformer models.', bullets=['Define self-attention and contrast it with traditional attention mechanisms used in sequence models like RNNs.', 'Describe why self-attention is critical for capturing dependencies irrespective of positional distance in input sequences.', 'Explain the role of self-attention in enabling parallelization during training over sequential architectures.', 'Provide an overview of transformer architecture to contextualize where self-attention fits.', 'Highlight key advantages such as long-range dependency handling and model scalability.'], target_words=350, tags=['conceptual', 'overview'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Mathematical Formulation of Self-Attention', goal='Detail the mathematical operations involved in computing self-attention scores and outputs.', bullets=['Describe the input representations: queries (Q), keys (K), and values (V), and how they are derived from the input embeddings.', 'Explain the dot-product attention formula: computing compatibility scores by QK^T and scaling by the square root of key dimension.', 'Outline the application of softmax to obtain attention weights and the weighted sum of values to produce output vectors.', 'Discuss dimensionalities of Q, K, V, and outputs to ensure clarity on tensor shapes.', 'Include possible variations such as scaled dot-product attention and mention why scaling is necessary.'], target_words=420, tags=['mathematical', 'technical'], requires_research=False, requires_citations=False, requires_code=True), Task(id=3, title='Implementation Sketch: Computing Self-Attention in Code', goal='Provide a minimal working example to implement scaled dot-product self-attention.', bullets=['Sketch a Python function using PyTorch or NumPy that takes matrices Q, K, V as inputs.', 'Compute attention scores with scaled dot-product, apply softmax, and multiply by V.', 'Demonstrate batch processing for multiple sequences and heads to highlight practical usage.', 'Explain handling of tensor dimensions and broadcasting to avoid common implementation errors.', 'Offer tips on ensuring numerical stability in softmax (e.g., subtracting max value before exponentiation).'], target_words=450, tags=['implementation', 'code_example', 'debugging'], requires_research=False, requires_citations=False, requires_code=True), Task(id=4, title='Multi-Head Attention: Extending Self-Attention', goal='Explain the concept and benefits of multi-head attention over single-head self-attention.', bullets=['Define multi-head attention as splitting queries, keys, and values into multiple smaller subspaces (heads).', 'Describe how parallel attention heads help the model attend to different subspaces and capture diverse information.', 'Explain the process of concatenating the output of all heads and applying a final linear projection.', 'Discuss trade-offs regarding performance and complexity introduced by multiple heads.', 'Highlight how multi-head attention mitigates the issue of focusing on limited features in single-head attention.'], target_words=380, tags=['conceptual', 'performance'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Edge Cases, Failure Modes, and Debugging Strategies', goal='Identify common pitfalls and how to diagnose and fix issues when imple ...
#  'sections': [(1,
#    '## Introduction to Self-Attention Mechanism\n\nSelf-attention is a core operation in transformer architectures that allows a model to weigh the importance of different parts of a single input sequence when encoding it. Unlike traditional attention mechanisms commonly used in sequence models such as RNNs or LSTMs—where attention is often applied over encoder-decoder interactions—self-attention operates within the same sequence. This means each position in the input attends to all other positions, generating context-aware representations that integrate global dependencies.\n\nOne of the primary strengths of self-attention is its ability to capture dependencies between tokens regardless of their positional distance. In contrast to RNNs, which process sequences sequentially and can struggle with long-range correlations due to vanishing gradients, self-attention directly models interactions across the entire sequence in a single step. This characteristic is crucial in complex tasks like natural language processing, where distant words can influence the meaning of the current word.\n\nFrom a computational standpoint, self-attention enables efficient parallelization. Since it does not rely on sequential state updates as RNNs do, all positions in the sequence can be processed simultaneously during training. This parallelism significantly reduces training time on modern hardware accelerators such as GPUs and TPUs, making it practical to train large-scale models over massive datasets.\n\nTransformers employ self-attention layers stacked with feed-forward neural networks and normalization layers, forming the fundamental building blocks of the architecture. Specifically, in the original transformer model, the encoder and decoder each contain multi-head self-attention modules that allow the model to jointly attend to information from different representation subspaces. This multi-head design further enhances the model’s capacity to capture diverse contextual cues within a sequence.\n\nKey advantages of self-attention include:\n\n- **Effective modeling of long-range dependencies:** Direct attention across the entire sequence eliminates the bottleneck of sequential memory.\n- **Scalability:** The architecture scales gracefully with sequence length and model depth due to parallel computation.\n- **Flexibility:** Self-attention can be adapted to various modalities beyond text, such as images or speech.\n\nOverall, self-attention is a fundamental enabler of the transformer’s success, balancing representational power with computational efficiency to handle complex sequence modeling tasks.'),
#   (2,
#    '## Mathematical Formulation of Self-Attention\n\nSelf-attention in transformer architectures operates on three fundamental input representations: queries (Q), keys (K), and values (V). These are all derived from the same input embeddings but linearly projected into separate subspaces through learned weight matrices. Given an input embedding matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (where \\(n\\) is the sequence length and \\(d\\) is the embedding dimension), the projections are defined as:\n\n\\[\nQ = X W^Q, \\quad K = X W^K, \\quad V = X W^V\n\\]\n\nwhere \\(W^Q, W^K, W^V \\in \\mathbb{R}^{d \\times d_k}\\) are trainable parameter matrices, and \\(d_k\\) is the dimensionality of the queries and keys. Typically, \\(d_k\\) is chosen to balance expressiveness and computational efficiency.\n\nThe core of self-attention is the **dot-product attention** mechanism, which calculates the compatibility between queries and keys. This compatibility is quantified by the matrix multiplication:\n\n\\[\n\\text{scores} = Q K^\\top\n\\]\n\nHere, \\(Q \\in \\mathbb{R}^{n \\times d_k}\\) and \\(K \\in \\mathbb{R}^{n \\times d_k}\\), so \\(\\text{scores} \\in \\mathbb{R}^{n \\times n}\\) represents the affinity of each position in the sequence with every other position.\n\nTo stabilize gradients and avoid extremely large values when input dimensions grow, the scores are scaled by \\(\\sqrt{d_k}\\):\n\n\\[\n\\text{scaled\\_scores} = \\frac{Q K^\\top}{\\sqrt{d_k}}\n\\]\n\nThis **scaled dot-product attention** is crucial for preventing gradients from vanishing or exploding during training.\n\nNext, the scaled scores pass through a softmax function, converting them into a probability distribution over the keys for each query position:\n\n\\[\n\\text{attention\\_weights} = \\text{softmax}\\left(\\frac{Q K^\\top}{\\sqrt{d_k}}\\right)\n\\]\n\nEach row of \\(\\text{attention\\_weights} \\in \\mathbb{R}^{n \\times n}\\) sums to 1, reflecting the relative importance of each key position to the query.\n\nThe output is computed as the weighted sum of the values:\n\n\\[\n\\text{output} = \\text{attention\\_weights} \\times V\n\\]\n\nwith \\(V \\in \\mathbb{R}^{n \\times d_v}\\), typically \\(d_v = d_k\\). Consequently, the output shape is \\(n \\times d_v\\), matching the sequence length and dimensionality of the values.\n\nConcretely, the tensor shapes flow as:\n\n- Input embeddings: \\(X \\in \\mathbb{R}^{n \\times d}\\)\n- Projections: \\(Q, K \\in \\mathbb{R}^{n \\times d_k}\\), \\(V \\in \\mathbb{R}^{n \\times d_v}\\)\n- Scores: \\(Q K^\\top \\in \\mathbb{R}^{n \\times n}\\)\n- Attention weights: \\(n \\times n\\)\n- Output: \\(n \\times d_v\\)\n\nThis formulation allows each position in the input sequence to attend dynamically to all other positions, enabling efficient context aggregation.\n\nBelow is a minimal PyTorch implementation of scaled dot-product attention illustrating these computations:\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef scaled_dot_product_attention(Q, K, V):\n    d_k = Q.size(-1)\n    # Compute raw attention scores\n    scores = torch.matmul(Q, K.transpose(-2, -1))  # (batch, seq_len, seq_len)\n    # Scale scores\n    scaled_scores = scores / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))\n    # Softmax to get attention weights\n    attention_weights = F.softmax(scaled_scores, dim=-1)\n    # Weighted sum of values\n    output = torch.matmul(attention_weights, V)  # (batch, seq_len, d_v)\n    return output, attention_weights\n```\n\nThis function assumes batched input tensors \\(Q, K, V\\) of shape `(batch_size, seq_len, d_k)` and returns the attended output with the same shape.\n\n**Summary of variations and importance of scaling:**\n\n- Without scaling, large values in the dot-product (due to high dimensionality \\(d_k\\)) push softmax into regions with very small gradients, hurting learning.\n- Scaling maintains gradient magnitudes at a stable range, improving convergence.\n- Some variations use ...
#   (3,
#    '## Implementation Sketch: Computing Self-Attention in Code\n\nHere is a minimal working example of scaled dot-product self-attention using PyTorch. This function accepts query (Q), key (K), and value (V) tensors, computes the attention scores, applies softmax weighting, and produces the attended output. It also supports batch processing with multiple sequences and heads.\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef scaled_dot_product_attention(Q, K, V, mask=None):\n    """\n    Compute scaled dot-product attention.\n    \n    Args:\n        Q: Queries tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        K: Keys tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        V: Values tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        mask: Optional mask tensor broadcastable to (batch_size, num_heads, seq_len, seq_len)\n    \n    Returns:\n        output: Attention output of shape (batch_size, num_heads, seq_len, head_dim)\n        attn_weights: Attention weights of shape (batch_size, num_heads, seq_len, seq_len)\n    """\n    d_k = Q.size(-1)  # head_dim for scaling\n    # Compute raw attention scores\n    scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(d_k, dtype=Q.dtype))\n    \n    if mask is not None:\n        scores = scores.masked_fill(mask == 0, float(\'-inf\'))\n    \n    # Numerical stability: subtract max before softmax\n    scores = scores - scores.max(dim=-1, keepdim=True).values\n    \n    attn_weights = F.softmax(scores, dim=-1)\n    output = torch.matmul(attn_weights, V)\n    \n    return output, attn_weights\n\n# Example usage\nbatch_size = 2\nnum_heads = 4\nseq_len = 5\nhead_dim = 64\n\n# Randomly initialized Q, K, V\nQ = torch.randn(batch_size, num_heads, seq_len, head_dim)\nK = torch.randn(batch_size, num_heads, seq_len, head_dim)\nV = torch.randn(batch_size, num_heads, seq_len, head_dim)\n\noutput, attn_weights = scaled_dot_product_attention(Q, K, V)\nprint("Output shape:", output.shape)        # (2, 4, 5, 64)\nprint("Attention weights shape:", attn_weights.shape)  # (2, 4, 5, 5)\n```\n\n### Tensor Dimensions and Broadcasting\n\n- The function expects `Q`, `K`, `V` shaped as `(batch_size, num_heads, seq_len, head_dim)`.\n- The transpose `K.transpose(-2, -1)` changes `K` shape to `(batch_size, num_heads, head_dim, seq_len)`, enabling batch matrix multiplication with `Q`.\n- Attention scores have shape `(batch_size, num_heads, seq_len, seq_len)`, representing the pairwise similarity of each query token to all key tokens.\n- The mask (if provided) must be broadcastable to the attention scores shape to selectively ignore certain positions (e.g., padding tokens or future tokens in autoregressive setups).\n\n### Numerical Stability Tips\n\nDirect exponentiation of raw attention scores can cause overflow or underflow. To mitigate this, subtract the maximum score value along the last dimension (the key dimension) before applying `softmax`. This does not change the output but improves numerical stability:\n\n```python\nscores = scores - scores.max(dim=-1, keepdim=True).values\n```\n\nThis pattern is essential in production-grade implementations to avoid NaNs or Inf values during training and inference.\n\n---\n\nThis straightforward yet extensible implementation forms the core computation for multi-head self-attention in transformers, balancing efficiency with clarity for debugging and further customization.'),
#   (4,
#    '## Multi-Head Attention: Extending Self-Attention\n\nMulti-head attention enhances the standard self-attention mechanism by dividing the input vectors—queries (Q), keys (K), and values (V)—into multiple smaller subspaces known as "heads." Instead of computing a single attention distribution over the entire embedding dimension, each head independently performs attention in a lower-dimensional space. Formally, if the model\'s embedding dimension is \\(d_{model}\\), and there are \\(h\\) heads, each head operates on subspaces of dimension \\(d_k = d_{model} / h\\).\n\nThis parallelization enables each head to focus on different parts or aspects of the input sequence, effectively allowing the transformer to capture a richer set of relationships and contextual features. For example, one head may learn syntactic dependencies while another attends to semantic roles. By diversifying attention focus across heads, the model can better generalize and represent complex interactions in the data.\n\nAfter computing attention outputs for each head separately, these outputs—each of size \\(d_k\\)—are concatenated back into a single vector of dimension \\(d_{model}\\). A final learned linear projection then transforms this concatenated representation, integrating the information gleaned from all heads into a unified output. This enables downstream layers to process a comprehensive, multi-faceted context embedding rather than a single viewpoint.\n\nHowever, the use of multiple heads introduces both computational and architectural trade-offs. Although parallel heads allow more expressive power, they increase the number of parameters and the computational complexity of the attention mechanism. Each head requires its own set of projection matrices for Q, K, V, and the output, escalating memory usage and compute time during both training and inference. Balancing the number of heads with available resources and task complexity is essential to optimizing model performance.\n\nCritically, multi-head attention mitigates the limitation inherent in single-head attention, where the model risks concentrating on only a limited subset of features or relationships. By distributing attention across multiple heads, the transformer captures diverse, complementary features simultaneously—improving robustness, interpretability, and ultimately, predictive performance. This architectural innovation is a cornerstone of the transformer\'s success in a wide range of sequence modeling tasks.'),
#   (5,
#    '## Edge Cases, Failure Modes, and Debugging Strategies\n\nWhen implementing self-attention mechanisms in transformers, several common issues can undermine model performance and cause training instability. Recognizing these pitfalls and applying targeted debugging strategies is essential.\n\n### Vanishing or Exploding Attention Scores\n\nSelf-attention computes scores as dot products of query and key vectors, which can grow large with higher dimensionality, leading to exploding values. Conversely, very small values can vanish. The standard mitigation is scaling the dot products by the inverse square root of the key dimension (i.e., dividing by \\(\\sqrt{d_k}\\)). This normalization stabilizes gradients and keeps scores within a manageable range, improving convergence.\n\n### Tensor Shape Mismatches\n\nA frequent source of runtime errors is shape incompatibility between query, key, and value tensors. Since attention involves matrix multiplication across multiple heads and batch dimensions, dimensions must align precisely:\n\n- Ensure queries and keys have shapes `[batch_size, num_heads, seq_len, head_dim]`.\n- Values typically share the last two dimensions with keys.\n  \nVerifying tensor shapes at each operation using assertions or print statements helps catch discrepancies early. APIs like PyTorch’s `.shape` or TensorFlow’s `.shape` can facilitate this inspection.\n\n### Numerical Instability in Softmax\n\nThe softmax function, applied to raw attention scores, can suffer overflow or underflow if input values are too large or too small. This causes unstable gradients and inconsistent attention outputs. Common remedies include:\n\n- Applying the log-sum-exp trick by subtracting the maximum score per sequence position before softmax calculation.\n- Normalizing inputs or clamping scores within a reasonable range before exponentiation.\n\nThese techniques preserve numerical stability without changing relative probabilities.\n\n### Padding Tokens and Masking Strategies\n\nSequences often have padding tokens to reach uniform length, but attending to these irrelevant positions leads to spurious context. Proper masking is critical:\n\n- Apply additive masks (e.g., large negative values like `-1e9`) to padding positions before softmax to nullify their influence.\n- Confirm mask shapes align with attention score matrices.\n  \nEffective masking prevents the model from learning incorrect dependencies on padded tokens.\n\n### Debugging Tips\n\n- **Monitor attention score distributions:** Track statistical summaries (mean, variance) during training to catch anomalies like collapsed or excessively sparse attention weights.\n- **Visualize attention maps:** Plotting attention heatmaps for sample inputs reveals whether the model attends to meaningful tokens.\n- **Layer-wise inspection:** Check intermediate outputs in multi-head layers to isolate problematic heads or timesteps.\n\n### Tools and Libraries\n\nSeveral tools streamline debugging self-attention:\n\n- **TensorBoard or Weights & Biases:** For visualizing attention weights and training metrics.\n- **Captum (PyTorch) or TF Explain:** Feature attribution libraries that shed light on model focus areas.\n- **Custom hooks or callbacks:** Inserted in training loops to extract and log attention matrices without disrupting flow.\n\nBy proactively validating tensor shapes, enforcing stable computations, and leveraging visualization, developers can efficiently diagnose and resolve self-attention implementation issues.'),
#   (6,
#    '## Performance and Computational Cost Considerations\n\nSelf-attention in transformers exhibits a quadratic time and space complexity with respect to the input sequence length \\(L\\). Specifically, the computation of the attention matrix requires evaluating \\(L \\times L\\) pairwise interactions between tokens, resulting in \\(O(L^2)\\) complexity. This quadratic scaling becomes a significant computational bottleneck as sequence length increases, both in terms of runtime and memory consumption.\n\nThe memory footprint of self-attention grows rapidly because the attention scores and intermediate tensors must be stored for all token pairs during training and inference. This challenge is exacerbated in long-sequence scenarios such as document classification or genome analysis, where the full dense attention matrix can exceed hardware memory limits, stalling training or leading to out-of-memory errors on GPUs/TPUs.\n\nTo mitigate these issues, several optimization techniques have been proposed:\n\n- **Sparse Attention:** Instead of computing attention scores for every pair, sparse attention restricts computations to a subset of token pairs based on locality or learned patterns. Examples include fixed windowed attention, block-sparse attention, and locality-sensitive hashing (LSH) attention. These methods reduce complexity closer to linear \\(O(L)\\) or \\(O(L \\log L)\\), dramatically improving scalability.\n\n- **Memory-Efficient Attention Variants:** Approaches like linearized attention approximate the softmax operation to avoid explicitly forming the full attention matrix. Kernel-based methods decompose attention to vector-matrix products that have linear complexity, simultaneously reducing memory usage.\n\nHardware acceleration on GPUs and TPUs plays a crucial role in improving performance by leveraging massively parallel matrix multiplication capabilities. Fused kernels and optimized libraries (e.g., cuBLAS, XLA compilers) minimize overhead and maximize throughput of self-attention operations.\n\nWhen designing or tuning transformers, striking a balance between model expressiveness and computational demands is essential. Longer sequences and richer attention patterns can enhance model capacity but increase latency and resource consumption. Practical strategies include:\n\n- Limiting input sequence length or truncating inputs.\n\n- Employing hierarchical or chunked processing.\n\n- Selecting appropriate sparse or efficient attention mechanisms tailored to the task.\n\n- Profiling and benchmarking on target hardware to meet latency constraints.\n\nOptimizing self-attention implementations requires an informed trade-off analysis considering the application, dataset characteristics, and available compute resources. Thoughtful choices can yield performant and scalable transformer models without prohibitive computational costs.'),
#   (7,
#    '## Summary and Future Outlook for Self-Attention\n\nSelf-attention has fundamentally reshaped sequence modeling by enabling each token in the input to dynamically attend to every other token. This mechanism allows transformers to capture long-range dependencies without the sequential bottlenecks of recurrent architectures. Key benefits include parallelizable computation, flexible contextualization, and scalability to diverse modalities, making self-attention a cornerstone for learning rich representations.\n\nDespite its advantages, self-attention’s quadratic complexity with respect to sequence length remains a challenge in large-scale applications. Emerging research tackles this with efficient transformer variants that approximate or sparsify attention patterns, significantly reducing memory and computational overhead while maintaining competitive accuracy. These innovations unlock new possibilities for deploying transformers in real-time and resource-constrained environments.\n\nToday, self-attention is central to state-of-the-art models across domains like natural language processing and computer vision. Its adaptability supports tasks ranging from language understanding and generation to image recognition and multimodal fusion. Mastery of self-attention is thus essential for advancing model performance and driving innovation.\n\nDevelopers and researchers are encouraged to implement and experiment with self-attention mechanisms. Practical experience in customizing attention layers, tuning hyperparameters, and profiling performance will deepen intuition and facilitate debugging in complex transformer systems.\n\nTo stay updated on transformer-related developments, consider engaging with resources such as research repositories, open-source projects like Hugging Face Transformers, and community forums focused on deep learning advancements. Continuous learning ensures leveraging the full potential of self-attention as this field rapidly evolves.'),
#   (1,
#    '## Introduction to Self-Attention Mechanism\n\nSelf-attention is a core operation in transformer architectures that allows a model to weigh the importance of different parts of a single input sequence when encoding it. Unlike traditional attention mechanisms commonly used in sequence models such as RNNs or LSTMs—where attention is often applied over encoder-decoder interactions—self-attention operates within the same sequence. This means each position in the input attends to all other positions, generating context-aware representations that integrate global dependencies.\n\nOne of the primary strengths of self-attention is its ability to capture dependencies between tokens regardless of their positional distance. In contrast to RNNs, which process sequences sequentially and can struggle with long-range correlations due to vanishing gradients, self-attention directly models interactions across the entire sequence in a single step. This characteristic is crucial in complex tasks like natural language processing, where distant words can influence the meaning of the current word.\n\nFrom a computational standpoint, self-attention enables efficient parallelization. Since it does not rely on sequential state updates as RNNs do, all positions in the sequence can be processed simultaneously during training. This parallelism significantly reduces training time on modern hardware accelerators such as GPUs and TPUs, making it practical to train large-scale models over massive datasets.\n\nTransformers employ self-attention layers stacked with feed-forward neural networks and normalization layers, forming the fundamental building blocks of the architecture. Specifically, in the original transformer model, the encoder and decoder each contain multi-head self-attention modules that allow the model to jointly attend to information from different representation subspaces. This multi-head design further enhances the model’s capacity to capture diverse contextual cues within a sequence.\n\nKey advantages of self-attention include:\n\n- **Effective modeling of long-range dependencies:** Direct attention across the entire sequence eliminates the bottleneck of sequential memory.\n- **Scalability:** The architecture scales gracefully with sequence length and model depth due to parallel computation.\n- **Flexibility:** Self-attention can be adapted to various modalities beyond text, such as images or speech.\n\nOverall, self-attention is a fundamental enabler of the transformer’s success, balancing representational power with computational efficiency to handle complex sequence modeling tasks.'),
#   (2,
#    '## Mathematical Formulation of Self-Attention\n\nSelf-attention in transformer architectures operates on three fundamental input representations: queries (Q), keys (K), and values (V). These are all derived from the same input embeddings but linearly projected into separate subspaces through learned weight matrices. Given an input embedding matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (where \\(n\\) is the sequence length and \\(d\\) is the embedding dimension), the projections are defined as:\n\n\\[\nQ = X W^Q, \\quad K = X W^K, \\quad V = X W^V\n\\]\n\nwhere \\(W^Q, W^K, W^V \\in \\mathbb{R}^{d \\times d_k}\\) are trainable parameter matrices, and \\(d_k\\) is the dimensionality of the queries and keys. Typically, \\(d_k\\) is chosen to balance expressiveness and computational efficiency.\n\nThe core of self-attention is the **dot-product attention** mechanism, which calculates the compatibility between queries and keys. This compatibility is quantified by the matrix multiplication:\n\n\\[\n\\text{scores} = Q K^\\top\n\\]\n\nHere, \\(Q \\in \\mathbb{R}^{n \\times d_k}\\) and \\(K \\in \\mathbb{R}^{n \\times d_k}\\), so \\(\\text{scores} \\in \\mathbb{R}^{n \\times n}\\) represents the affinity of each position in the sequence with every other position.\n\nTo stabilize gradients and avoid extremely large values when input dimensions grow, the scores are scaled by \\(\\sqrt{d_k}\\):\n\n\\[\n\\text{scaled\\_scores} = \\frac{Q K^\\top}{\\sqrt{d_k}}\n\\]\n\nThis **scaled dot-product attention** is crucial for preventing gradients from vanishing or exploding during training.\n\nNext, the scaled scores pass through a softmax function, converting them into a probability distribution over the keys for each query position:\n\n\\[\n\\text{attention\\_weights} = \\text{softmax}\\left(\\frac{Q K^\\top}{\\sqrt{d_k}}\\right)\n\\]\n\nEach row of \\(\\text{attention\\_weights} \\in \\mathbb{R}^{n \\times n}\\) sums to 1, reflecting the relative importance of each key position to the query.\n\nThe output is computed as the weighted sum of the values:\n\n\\[\n\\text{output} = \\text{attention\\_weights} \\times V\n\\]\n\nwith \\(V \\in \\mathbb{R}^{n \\times d_v}\\), typically \\(d_v = d_k\\). Consequently, the output shape is \\(n \\times d_v\\), matching the sequence length and dimensionality of the values.\n\nConcretely, the tensor shapes flow as:\n\n- Input embeddings: \\(X \\in \\mathbb{R}^{n \\times d}\\)\n- Projections: \\(Q, K \\in \\mathbb{R}^{n \\times d_k}\\), \\(V \\in \\mathbb{R}^{n \\times d_v}\\)\n- Scores: \\(Q K^\\top \\in \\mathbb{R}^{n \\times n}\\)\n- Attention weights: \\(n \\times n\\)\n- Output: \\(n \\times d_v\\)\n\nThis formulation allows each position in the input sequence to attend dynamically to all other positions, enabling efficient context aggregation.\n\nBelow is a minimal PyTorch implementation of scaled dot-product attention illustrating these computations:\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef scaled_dot_product_attention(Q, K, V):\n    d_k = Q.size(-1)\n    # Compute raw attention scores\n    scores = torch.matmul(Q, K.transpose(-2, -1))  # (batch, seq_len, seq_len)\n    # Scale scores\n    scaled_scores = scores / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))\n    # Softmax to get attention weights\n    attention_weights = F.softmax(scaled_scores, dim=-1)\n    # Weighted sum of values\n    output = torch.matmul(attention_weights, V)  # (batch, seq_len, d_v)\n    return output, attention_weights\n```\n\nThis function assumes batched input tensors \\(Q, K, V\\) of shape `(batch_size, seq_len, d_k)` and returns the attended output with the same shape.\n\n**Summary of variations and importance of scaling:**\n\n- Without scaling, large values in the dot-product (due to high dimensionality \\(d_k\\)) push softmax into regions with very small gradients, hurting learning.\n- Scaling maintains gradient magnitudes at a stable range, improving convergence.\n- Some variations use ...
#   (3,
#    '## Implementation Sketch: Computing Self-Attention in Code\n\nHere is a minimal working example of scaled dot-product self-attention using PyTorch. This function accepts query (Q), key (K), and value (V) tensors, computes the attention scores, applies softmax weighting, and produces the attended output. It also supports batch processing with multiple sequences and heads.\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef scaled_dot_product_attention(Q, K, V, mask=None):\n    """\n    Compute scaled dot-product attention.\n    \n    Args:\n        Q: Queries tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        K: Keys tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        V: Values tensor of shape (batch_size, num_heads, seq_len, head_dim)\n        mask: Optional mask tensor broadcastable to (batch_size, num_heads, seq_len, seq_len)\n    \n    Returns:\n        output: Attention output of shape (batch_size, num_heads, seq_len, head_dim)\n        attn_weights: Attention weights of shape (batch_size, num_heads, seq_len, seq_len)\n    """\n    d_k = Q.size(-1)  # head_dim for scaling\n    # Compute raw attention scores\n    scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(d_k, dtype=Q.dtype))\n    \n    if mask is not None:\n        scores = scores.masked_fill(mask == 0, float(\'-inf\'))\n    \n    # Numerical stability: subtract max before softmax\n    scores = scores - scores.max(dim=-1, keepdim=True).values\n    \n    attn_weights = F.softmax(scores, dim=-1)\n    output = torch.matmul(attn_weights, V)\n    \n    return output, attn_weights\n\n# Example usage\nbatch_size = 2\nnum_heads = 4\nseq_len = 5\nhead_dim = 64\n\n# Randomly initialized Q, K, V\nQ = torch.randn(batch_size, num_heads, seq_len, head_dim)\nK = torch.randn(batch_size, num_heads, seq_len, head_dim)\nV = torch.randn(batch_size, num_heads, seq_len, head_dim)\n\noutput, attn_weights = scaled_dot_product_attention(Q, K, V)\nprint("Output shape:", output.shape)        # (2, 4, 5, 64)\nprint("Attention weights shape:", attn_weights.shape)  # (2, 4, 5, 5)\n```\n\n### Tensor Dimensions and Broadcasting\n\n- The function expects `Q`, `K`, `V` shaped as `(batch_size, num_heads, seq_len, head_dim)`.\n- The transpose `K.transpose(-2, -1)` changes `K` shape to `(batch_size, num_heads, head_dim, seq_len)`, enabling batch matrix multiplication with `Q`.\n- Attention scores have shape `(batch_size, num_heads, seq_len, seq_len)`, representing the pairwise similarity of each query token to all key tokens.\n- The mask (if provided) must be broadcastable to the attention scores shape to selectively ignore certain positions (e.g., padding tokens or future tokens in autoregressive setups).\n\n### Numerical Stability Tips\n\nDirect exponentiation of raw attention scores can cause overflow or underflow. To mitigate this, subtract the maximum score value along the last dimension (the key dimension) before applying `softmax`. This does not change the output but improves numerical stability:\n\n```python\nscores = scores - scores.max(dim=-1, keepdim=True).values\n```\n\nThis pattern is essential in production-grade implementations to avoid NaNs or Inf values during training and inference.\n\n---\n\nThis straightforward yet extensible implementation forms the core computation for multi-head self-attention in transformers, balancing efficiency with clarity for debugging and further customization.'),
#   (4,
#    '## Multi-Head Attention: Extending Self-Attention\n\nMulti-head attention enhances the standard self-attention mechanism by dividing the input vectors—queries (Q), keys (K), and values (V)—into multiple smaller subspaces known as "heads." Instead of computing a single attention distribution over the entire embedding dimension, each head independently performs attention in a lower-dimensional space. Formally, if the model\'s embedding dimension is \\(d_{model}\\), and there are \\(h\\) heads, each head operates on subspaces of dimension \\(d_k = d_{model} / h\\).\n\nThis parallelization enables each head to focus on different parts or aspects of the input sequence, effectively allowing the transformer to capture a richer set of relationships and contextual features. For example, one head may learn syntactic dependencies while another attends to semantic roles. By diversifying attention focus across heads, the model can better generalize and represent complex interactions in the data.\n\nAfter computing attention outputs for each head separately, these outputs—each of size \\(d_k\\)—are concatenated back into a single vector of dimension \\(d_{model}\\). A final learned linear projection then transforms this concatenated representation, integrating the information gleaned from all heads into a unified output. This enables downstream layers to process a comprehensive, multi-faceted context embedding rather than a single viewpoint.\n\nHowever, the use of multiple heads introduces both computational and architectural trade-offs. Although parallel heads allow more expressive power, they increase the number of parameters and the computational complexity of the attention mechanism. Each head requires its own set of projection matrices for Q, K, V, and the output, escalating memory usage and compute time during both training and inference. Balancing the number of heads with available resources and task complexity is essential to optimizing model performance.\n\nCritically, multi-head attention mitigates the limitation inherent in single-head attention, where the model risks concentrating on only a limited subset of features or relationships. By distributing attention across multiple heads, the transformer captures diverse, complementary features simultaneously—improving robustness, interpretability, and ultimately, predictive performance. This architectural innovation is a cornerstone of the transformer\'s success in a wide range of sequence modeling tasks.'),
#   (5,
#    '## Edge Cases, Failure Modes, and Debugging Strategies\n\nWhen implementing self-attention mechanisms in transformers, several common issues can undermine model performance and cause training instability. Recognizing these pitfalls and applying targeted debugging strategies is essential.\n\n### Vanishing or Exploding Attention Scores\n\nSelf-attention computes scores as dot products of query and key vectors, which can grow large with higher dimensionality, leading to exploding values. Conversely, very small values can vanish. The standard mitigation is scaling the dot products by the inverse square root of the key dimension (i.e., dividing by \\(\\sqrt{d_k}\\)). This normalization stabilizes gradients and keeps scores within a manageable range, improving convergence.\n\n### Tensor Shape Mismatches\n\nA frequent source of runtime errors is shape incompatibility between query, key, and value tensors. Since attention involves matrix multiplication across multiple heads and batch dimensions, dimensions must align precisely:\n\n- Ensure queries and keys have shapes `[batch_size, num_heads, seq_len, head_dim]`.\n- Values typically share the last two dimensions with keys.\n  \nVerifying tensor shapes at each operation using assertions or print statements helps catch discrepancies early. APIs like PyTorch’s `.shape` or TensorFlow’s `.shape` can facilitate this inspection.\n\n### Numerical Instability in Softmax\n\nThe softmax function, applied to raw attention scores, can suffer overflow or underflow if input values are too large or too small. This causes unstable gradients and inconsistent attention outputs. Common remedies include:\n\n- Applying the log-sum-exp trick by subtracting the maximum score per sequence position before softmax calculation.\n- Normalizing inputs or clamping scores within a reasonable range before exponentiation.\n\nThese techniques preserve numerical stability without changing relative probabilities.\n\n### Padding Tokens and Masking Strategies\n\nSequences often have padding tokens to reach uniform length, but attending to these irrelevant positions leads to spurious context. Proper masking is critical:\n\n- Apply additive masks (e.g., large negative values like `-1e9`) to padding positions before softmax to nullify their influence.\n- Confirm mask shapes align with attention score matrices.\n  \nEffective masking prevents the model from learning incorrect dependencies on padded tokens.\n\n### Debugging Tips\n\n- **Monitor attention score distributions:** Track statistical summaries (mean, variance) during training to catch anomalies like collapsed or excessively sparse attention weights.\n- **Visualize attention maps:** Plotting attention heatmaps for sample inputs reveals whether the model attends to meaningful tokens.\n- **Layer-wise inspection:** Check intermediate outputs in multi-head layers to isolate problematic heads or timesteps.\n\n### Tools and Libraries\n\nSeveral tools streamline debugging self-attention:\n\n- **TensorBoard or Weights & Biases:** For visualizing attention weights and training metrics.\n- **Captum (PyTorch) or TF Explain:** Feature attribution libraries that shed light on model focus areas.\n- **Custom hooks or callbacks:** Inserted in training loops to extract and log attention matrices without disrupting flow.\n\nBy proactively validating tensor shapes, enforcing stable computations, and leveraging visualization, developers can efficiently diagnose and resolve self-attention implementation issues.'),
#   (6,
#    '## Performance and Computational Cost Considerations\n\nSelf-attention in transformers exhibits a quadratic time and space complexity with respect to the input sequence length \\(L\\). Specifically, the computation of the attention matrix requires evaluating \\(L \\times L\\) pairwise interactions between tokens, resulting in \\(O(L^2)\\) complexity. This quadratic scaling becomes a significant computational bottleneck as sequence length increases, both in terms of runtime and memory consumption.\n\nThe memory footprint of self-attention grows rapidly because the attention scores and intermediate tensors must be stored for all token pairs during training and inference. This challenge is exacerbated in long-sequence scenarios such as document classification or genome analysis, where the full dense attention matrix can exceed hardware memory limits, stalling training or leading to out-of-memory errors on GPUs/TPUs.\n\nTo mitigate these issues, several optimization techniques have been proposed:\n\n- **Sparse Attention:** Instead of computing attention scores for every pair, sparse attention restricts computations to a subset of token pairs based on locality or learned patterns. Examples include fixed windowed attention, block-sparse attention, and locality-sensitive hashing (LSH) attention. These methods reduce complexity closer to linear \\(O(L)\\) or \\(O(L \\log L)\\), dramatically improving scalability.\n\n- **Memory-Efficient Attention Variants:** Approaches like linearized attention approximate the softmax operation to avoid explicitly forming the full attention matrix. Kernel-based methods decompose attention to vector-matrix products that have linear complexity, simultaneously reducing memory usage.\n\nHardware acceleration on GPUs and TPUs plays a crucial role in improving performance by leveraging massively parallel matrix multiplication capabilities. Fused kernels and optimized libraries (e.g., cuBLAS, XLA compilers) minimize overhead and maximize throughput of self-attention operations.\n\nWhen designing or tuning transformers, striking a balance between model expressiveness and computational demands is essential. Longer sequences and richer attention patterns can enhance model capacity but increase latency and resource consumption. Practical strategies include:\n\n- Limiting input sequence length or truncating inputs.\n\n- Employing hierarchical or chunked processing.\n\n- Selecting appropriate sparse or efficient attention mechanisms tailored to the task.\n\n- Profiling and benchmarking on target hardware to meet latency constraints.\n\nOptimizing self-attention implementations requires an informed trade-off analysis considering the application, dataset characteristics, and available compute resources. Thoughtful choices can yield performant and scalable transformer models without prohibitive computational costs.'),
#   (7,
#    '## Summary and Future Outlook for Self-Attention\n\nSelf-attention has fundamentally reshaped sequence modeling by enabling each token in the input to dynamically attend to every other token. This mechanism allows transformers to capture long-range dependencies without the sequential bottlenecks of recurrent architectures. Key benefits include parallelizable computation, flexible contextualization, and scalability to diverse modalities, making self-attention a cornerstone for learning rich representations.\n\nDespite its advantages, self-attention’s quadratic complexity with respect to sequence length remains a challenge in large-scale applications. Emerging research tackles this with efficient transformer variants that approximate or sparsify attention patterns, significantly reducing memory and computational overhead while maintaining competitive accuracy. These innovations unlock new possibilities for deploying transformers in real-time and resource-constrained environments.\n\nToday, self-attention is central to state-of-the-art models across domains like natural language processing and computer vision. Its adaptability supports tasks ranging from language understanding and generation to image recognition and multimodal fusion. Mastery of self-attention is thus essential for advancing model performance and driving innovation.\n\nDevelopers and researchers are encouraged to implement and experiment with self-attention mechanisms. Practical experience in customizing attention layers, tuning hyperparameters, and profiling performance will deepen intuition and facilitate debugging in complex transformer systems.\n\nTo stay updated on transformer-related developments, consider engaging with resources such as research repositories, open-source projects like Hugging Face Transformers, and community forums focused on deep learning advancements. Continuous learning ensures leveraging the full potential of self-attention as this field rapidly evolves.')],
#  'merged_md': '# Understanding Self-Attention in Transformer Architecture\n\n## Introduction to Self-Attention Mechanism\n\nSelf-attention is a core operation in transformer architectures that allows a model to weigh the importance of different parts of a single input sequence when encoding it. Unlike traditional attention mechanisms commonly used in sequence models such as RNNs or LSTMs—where attention is often applied over encoder-decoder interactions—self-attention operates within the same sequence. This means each position in the input attends to all other positions, generating context-aware representations that integrate global dependencies.\n\nOne of the primary strengths of self-attention is its ability to capture dependencies between tokens regardless of their positional distance. In contrast to RNNs, which process sequences sequentially and can struggle with long-range correlations due to vanishing gradients, self-attention directly models interactions across the entire sequence in a single step. This characteristic is crucial in complex tasks like natural language processing, where distant words can influence the meaning of the current word.\n\nFrom a computational standpoint, self-attention enables efficient parallelization. Since it does not rely on sequential state updates as RNNs do, all positions in the sequence can be processed simultaneously during training. This parallelism significantly reduces training time on modern hardware accelerators such as GPUs and TPUs, making it practical to train large-scale models over massive datasets.\n\nTransformers employ self-attention layers stacked with feed-forward neural networks and normalization layers, forming the fundamental building blocks of the architecture. Specifically, in the original transformer model, the encoder and decoder each contain multi-head self-attention modules that allow the model to jointly attend to information from different representation subspaces. This multi-head design further enhances the model’s capacity to capture diverse contextual cues within a sequence.\n\nKey advantages of self-attention include:\n\n- **Effective modeling of long-range dependencies:** Direct attention across the entire sequence eliminates the bottleneck of sequential memory.\n- **Scalability:** The architecture scales gracefully with sequence length and model depth due to parallel computation.\n- **Flexibility:** Self-attention can be adapted to various modalities beyond text, such as images or speech.\n\nOverall, self-attention is a fundamental enabler of the transformer’s success, balancing representational power with computational efficiency to handle complex sequence modeling tasks.\n\n## Mathematical Formulation of Self-Attention\n\nSelf-attention in transformer architectures operates on three fundamental input representations: queries (Q), keys (K), and values (V). These are all derived from the same input embeddings but linearly projected into separate subspaces through learned weight matrices. Given an input embedding matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (where \\(n\\) is the sequence length and \\(d\\) is the embedding dimension), the projections are defined as:\n\n\\[\nQ = X W^Q, \\quad K = X W^K, \\quad V = X W^V\n\\]\n\nwhere \\(W^Q, W^K, W^V \\in \\mathbb{R}^{d \\times d_k}\\) are trainable parameter matrices, and \\(d_k\\) is the dimensionality of the queries and keys. Typically, \\(d_k\\) is chosen to balance expressiveness and computational efficiency.\n\nThe core of self-attention is the **dot-product attention** mechanism, which calculates the compatibility between queries and keys. This compatibility is quantified by the matrix multiplication:\n\n\\[\n\\text{scores} = Q K^\\top\n\\]\n\nHere, \\(Q \\in \\mathbb{R}^{n \\times d_k}\\) and \\(K \\in \\mathbb{R}^{n \\times d_k}\\), so \\(\\text{scores} \\in \\mathbb{R}^{n \\times n}\\) represents the affinity of each position in the sequence with every other position.\n\nTo stabilize gradients a ...
#  'md_with_placeholders': '# Understanding Self-Attention in Transformer Architecture\n\n## Introduction to Self-Attention Mechanism\n\nSelf-attention is a core operation in transformer architectures that allows a model to weigh the importance of different parts of a single input sequence when encoding it. Unlike traditional attention mechanisms commonly used in sequence models such as RNNs or LSTMs\r\n\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n[[IMAGE_1]]\n\nthis means each position in the input attends to all other positions, generating context-aware representations that integrate global dependencies.\n\nOne of the primary strengths of self-attention is its ability to capture dependencies between tokens regardless of their positional distance. In contrast to RNNs, which process sequences sequentially and can struggle with long-range correlations due to vanishing gradients, self-attention directly models interactions across the entire sequence in a single step. This characteristic is crucial in complex tasks like natural language processing, where distant words can influence the meaning of the current word.\n\nFrom a computational standpoint, self-attention enables efficient parallelization. Since it does not rely on sequential state updates as RNNs do, all positions in the sequence can be processed simultaneously during training. This parallelism significantly reduces training time on modern hardware accelerators such as GPUs and TPUs, making it practical to train large-scale models over massive datasets.\n\nTransformers employ self-attention layers stacked with feed-forward neural networks and normalization layers, forming the fundamental building blocks of the architecture. Specifically, in the original transformer model, the encoder and decoder each contain multi-head self-attention modules that allow the model to jointly attend to information from different representation subspaces. This multi-head design further enhances the model\x17s capacity to capture diverse contextual cues within a sequence.\n\nKey advantages of self-attention include:\n\n- **Effective modeling of long-range dependencies:** Direct attention across the entire sequence eliminates the bottleneck of sequential memory.\n- **Scalability:** The architecture scales gracefully with sequence length and model depth due to parallel computation.\n- **Flexibility:** Self-attention can be adapted to various modalities beyond text, such as images or speech.\n\nOverall, self-attention is a fundamental enabler of the transformer\x17s success, balancing representational power with computational efficiency to handle complex sequence modeling tasks.\n\n## Mathematical Formulation of Self-Attention\n\nSelf-attention in transformer architectures operates on three fundamental input representations: queries (Q), keys (K), and values (V). These are all derived from the same input embeddings but linearly projected into separate subspaces through learned weight matrices. Given an input embedding matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (where \\(n\\) is the sequence length and \\(d\\) is the embedding dimension), the projections are defined as:\n\n\\[\nQ = X W^Q, \\quad K = X W^K, \\quad V = X W^V\n\\]\n\nwhere \\(W^Q, W^K, W^V \\in \\mathbb{R}^{d \\times d_k}\\) are trainable parameter matrices, and \\(d_k\\) is the dimensionality of the queries and keys. Typically, \\(d_k\\) is chosen to balance expressiveness and computational efficiency.\n\nThe core of self-attention is the **dot-product attention** mechanism, which calculates the compatibility between queries and keys. This compatibility is quantified by the matrix multiplication:\n\n\\[\n\\text{scores} = Q K^\\top\n\\]\n\nHere, \\(Q \\in \\mathbb{R}^{n \\times d_k}\\) and \\(K \\in \\mathbb{R}^{n \\times d_k}\\), so \\(\\text{scores} \\in \\mathbb{R}^{n \\times n}\\) represents the affinity of each position in the sequence with every other position.\n\nTo stabilize gradients and avoid extremely large values when in ...
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'self_attention_schema.png',
#    'alt': 'Diagram of self-attention mechanism in a transformer showing each input token attending to all others.',
#    'caption': 'Illustration of the self-attention mechanism where each token attends to all other tokens in a sequence to generate context-aware representations.',
#    'prompt': 'Diagram showing a sequence of tokens with arrows indicating that each token attends to every other token, labeled axes indicating position in the sequence, with simple token embeddings visualized as vectors at each position, illustrating the concept of self-attention.',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_2]]',
#    'filename': 'multi_head_attention.png',
#    'alt': 'Diagram of multi-head self-attention architecture showing multiple attention heads processing split projections of queries, keys, and values, then concatenated.',
#    'caption': 'Structure of multi-head attention: input embeddings are projected into multiple heads, each performing scaled dot-product attention independently, followed by concatenation and a final linear projection.',
#    'prompt': 'Schematic of multi-head attention in transformers: input embeddings split into multiple heads with separate projection matrices for Q, K, V, parallel scaled dot-product attention computations shown as separate modules, outputs concatenated into a single vector and passed through a linear layer.',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_3]]',
#    'filename': 'attention_complexity_chart.png',
#    'alt': 'Chart contrasting quadratic complexity of standard self-attention and linear or sparse attention optimizations.',
#    'caption': 'Comparison of computational complexity for standard self-attention (quadratic in sequence length) versus optimized attention mechanisms (sparse, linearized) that reduce runtime and memory usage.',
#    'prompt': 'Chart or graph illustrating computational and memory complexity with respect to input sequence length for standard self-attention versus optimized methods like sparse or linearized attention, highlighting the quadratic vs. linear or sub-quadratic scaling.',
#    'size': '1024x1024',
#    'quality': 'high'}],
#  'final': '# Understanding Self-Attention in Transformer Architecture\n\n## Introduction to Self-Attention Mechanism\n\nSelf-attention is a core operation in transformer architectures that allows a model to weigh the importance of different parts of a single input sequence when encoding it. Unlike traditional attention mechanisms commonly used in sequence models such as RNNs or LSTMs\r\n\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n![Diagram of self-attention mechanism in a transformer showing each input token attending to all others.](images/self_attention_schema.png)\n*Illustration of the self-attention mechanism where each token attends to all other tokens in a sequence to generate context-aware representations.*\n\nthis means each position in the input attends to all other positions, generating context-aware representations that integrate global dependencies.\n\nOne of the primary strengths of self-attention is its ability to capture dependencies between tokens regardless of their positional distance. In contrast to RNNs, which process sequences sequentially and can struggle with long-range correlations due to vanishing gradients, self-attention directly models interactions across the entire sequence in a single step. This characteristic is crucial in complex tasks like natural language processing, where distant words can influence the meaning of the current word.\n\nFrom a computational standpoint, self-attention enables efficient parallelization. Since it does not rely on sequential state updates as RNNs do, all positions in the sequence can be processed simultaneously during training. This parallelism significantly reduces training time on modern hardware accelerators such as GPUs and TPUs, making it practical to train large-scale models over massive datasets.\n\nTransformers employ self-attention layers stacked with feed-forward neural networks and normalization layers, forming the fundamental building blocks of the architecture. Specifically, in the original transformer model, the encoder and decoder each contain multi-head self-attention modules that allow the model to jointly attend to information from different representation subspaces. This multi-head design further enhances the model\x17s capacity to capture diverse contextual cues within a sequence.\n\nKey advantages of self-attention include:\n\n- **Effective modeling of long-range dependencies:** Direct attention across the entire sequence eliminates the bottleneck of sequential memory.\n- **Scalability:** The architecture scales gracefully with sequence length and model depth due to parallel computation.\n- **Flexibility:** Self-attention can be adapted to various modalities beyond text, such as images or speech.\n\nOverall, self-attention is a fundamental enabler of the transformer\x17s success, balancing representational power with computational efficiency to handle complex sequence modeling tasks.\n\n## Mathematical Formulation of Self-Attention\n\nSelf-attention in transformer architectures operates on three fundamental input representations: queries (Q), keys (K), and values (V). These are all derived from the same input embeddings but linearly projected into separate subspaces through learned weight matrices. Given an input embedding matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (where \\(n\\) is the sequence length and \\(d\\) is the embedding dimension), the projections are defined as:\n\n\\[\nQ = X W^Q, \\quad K = X W^K, \\quad V = X W^V\n\\]\n\nwhere \\(W^Q, W^K, W^V \\in \\mathbb{R}^{d \\times d_k}\\) are trainable parameter matrices, and \\(d_k\\) is the dimensionality of the queries and keys. Typically, \\(d_k\\) is chosen to balance expressiveness and computational efficiency.\n\nThe core of self-attention is the **dot-product attention** mechanism, which calculates the compatibility between queries and keys. This compatibility is quantified by the matrix multiplication:\n\n\\[\n\\text{scores} = Q K^\\top\n\\]\n\nHere, \\(Q \\in \\mathbb{R}^{n \\ti ...
